# %% [markdown]
# <a href="https://colab.research.google.com/github/stmeinert/Recolorization_IANN/blob/main/Test_image_comparision_deepface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deepface
# Out:
# ...
#      |████████████████████████████████| 63 kB 2.5 MB/s
# ...
#      |████████████████████████████████| 2.3 MB 65.7 MB/s
# ...
#      |████████████████████████████████| 462 kB 60.5 MB/s
# ...

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'color2.jpeg', 'gray_scale2.jpeg', 'sample_data']

# %%
from deepface import DeepFace
import matplotlib.pyplot as plt
import PIL.Image
verification1 = DeepFace.verify(img1_path = "color2.jpeg", img2_path = "gray_scale2.jpeg")
print(verification1)


verification2 = DeepFace.verify(img1_path = "gray_scale2.jpeg", img2_path = "color2.jpeg")
print(verification2)

verification3 = DeepFace.verify(img1_path = "gray_scale.jpeg", img2_path = "color2.jpeg")
print(verification3)

verification4 = DeepFace.verify(img1_path = "gray_scale.jpeg", img2_path = "color.jpeg")
print(verification4)

verification5 = DeepFace.verify(img1_path = "gray_scale.jpeg", img2_path = "gray_scale2.jpeg")
print(verification5)
# Out:
# {'verified': True, 'distance': 0.023864761085567898, 'threshold': 0.4, 'model': 'VGG-Face', 'detector_backend': 'opencv', 'similarity_metric': 'cosine'}
# {'verified': True, 'distance': 0.023864761085567898, 'threshold': 0.4, 'model': 'VGG-Face', 'detector_backend': 'opencv', 'similarity_metric': 'cosine'}
# {'verified': False, 'distance': 0.7562007838782451, 'threshold': 0.4, 'model': 'VGG-Face', 'detector_backend': 'opencv', 'similarity_metric': 'cosine'}
# {'verified': True, 'distance': 0.02931515510252547, 'threshold': 0.4, 'model': 'VGG-Face', 'detector_backend': 'opencv', 'similarity_metric': 'cosine'}
# {'verified': False, 'distance': 0.7278421223623999, 'threshold': 0.4, 'model': 'VGG-Face', 'detector_backend': 'opencv', 'similarity_metric': 'cosine'}

# %%
PIL.Image.open("gray_scale2.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7F9B9C248A50>

# %%
PIL.Image.open("color2.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7F9C2C29D650>

# %%
PIL.Image.open("color.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7F9B9C20F850>

# %%
PIL.Image.open("gray_scale.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7F9B9C19C0D0>
